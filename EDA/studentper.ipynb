# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.shape  # row,columns
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()  # no any null value in the dataset
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# univariate analysis

# %%
df.school.value_counts(normalize=True)
# Out:
# school
# GP    0.651772
# MS    0.348228
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="school",data=df,palette="viridis")
plt.title("NO OF SCHOOL COUNT")
plt.xlabel("count of school")
plt.ylabel("count")
plt.show()

# %%
# gp has higher number of count

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.histplot(x="age",kde=True,data=df,bins=20,palette="Set2")
plt.show()  # most of the students are of 16 or 17 age less is 21 and 20

# %%
sns.countplot(x="address",data=df,palette="Set2")
plt.show()  # most of the students are from urban region

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
Reason = df.reason.value_counts()
plt.pie(Reason,labels=Reason.index,autopct="%1.1f%%")
plt.show()  # most the std joined the schl becouse of course

# %%
act = df.activities.value_counts()
plt.pie(act,labels=act.index,autopct="%1.1f%%")
plt.show()   # majority will not participated in activities

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
weekalc = df.Walc.value_counts()
plt.pie(weekalc,labels=weekalc.index,autopct="%1.1f%%")
plt.show()
# 45 students take 5 times a week take alchol

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(x="Medu",data=df,palette="Set2")
plt.title("mother education graph")
plt.xlabel("Mother education")
plt.ylabel("Count")



plt.subplot(1,2,2)
sns.countplot(x= "Fedu",data=df,palette="viridis")
plt.title("Father education graph")
plt.xlabel("Mother education")
plt.ylabel("count")
plt.show()

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.barplot(x="studytime",y="G3",data=df)
# Out:
# <Axes: xlabel='studytime', ylabel='G3'>

# %%
df.G3.unique()
# Out:
# array([11, 12, 14, 13, 17, 15,  7, 10, 16,  9,  8, 18,  6,  0,  1,  5, 19])

# %%
df.G2.unique()
# Out:
# array([11, 13, 14, 12, 16, 17,  8, 10, 15,  9,  7,  6, 18, 19,  0,  5])

# %%
df.G1.unique()
# Out:
# array([ 0,  9, 12, 14, 11, 13, 10, 15, 17,  8, 16, 18,  7,  6,  5,  4, 19])

# %%
df.studytime.value_counts()
# Out:
# studytime
# 2    305
# 1    212
# 3     97
# 4     35
# Name: count, dtype: int64

# %%
sns.barplot(x= "internet",y="G3",data=df)  # student who are using internet get more marks in G3
# Out:
# <Axes: xlabel='internet', ylabel='G3'>

# %%
# multivariate analysis
sns.barplot(x="sex",y="G3",hue="address",data=df,palette="Set2")  # females are coming from urban area getting more marks than rural
# Out:
# <Axes: xlabel='sex', ylabel='G3'>

# %%
cat_col = [i for i in df.columns if df[i].dtype == "object"]
cat_col
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic']

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df[num_col],palette="Set2")
# Out:
# <Axes: >

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True,fmt=".2f",cmap="coolwarm")
# Out:
# <Axes: >

# %%
# strong negative corr are also available

# %%
# outlier detection 

students_grade_df = df.copy()
students_grade_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
students_grade_df = students_grade_df.drop(["G1","G2","G3"],axis=1)

# %%
x = students_grade_df.iloc[:,:-1]
y =students_grade_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train ,y_test = train_test_split(x,y,test_size=0.30,random_state=1)

# %%
le = LabelEncoder()

# %%
ans = le.fit_transform(students_grade_df.loc[:,"school"])

# %%
students_grade_df.loc[:,"school"] = ans
