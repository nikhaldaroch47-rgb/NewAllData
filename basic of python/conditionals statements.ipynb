# %%
# CONDITIONAL STATEMENTS ->> THE CONDE WILL BE EXECUTED ON PRECONDITION 
''' sytax of if i ==
if condition :
    block of code '''
a = 100
if a > 0:
    print("a is greater than zero")
# Out:
# a is greater than zero

# %%
temp = 27 
if temp >= 25:
    print("hot day")
# Out:
# hot day

# %%
num = 78
if num % 2 == 0:
    print("num ->> even ")
# Out:
# num ->> even

# %%
# now mutiple conditions 
maths_marks = 70
science_marks = 80
if ((maths_marks > 60) & (science_marks > 70)):
    print("student is intellegent ")
# Out:
# student is intellegent

# %%
a = 41 
b = 20
if ((a % 5 == 0) & (b % 5 == 0)):
    print("both the numbers are even")
else:
        print("num is odd")
# Out:
# num is odd

# %%
# in real life we have multiple conditions.. 
# syntax 
# if some condition
# excute code 
# elif some condition 
# else

# %%
a = 10000
if a > 2000:
    print("a is very huge")
elif a < 100 :
    print("a less than 100")
elif a  > 100:
    print("a is greater 100") 
else:
    print("a is equals to 100")
# Out:
# a is very huge

# %%
score = 65
if (score>=90):
    print("grade is A")
elif (70<=score<=80):
    print("grade is B")
elif (60<=score<=70):
    print("grade is C")
else:
    print("grade is D")
# Out:
# grade is C

# %%
# nested if else 
x = 6
y = 7
if x > 5:
    if y > 5:
        print("x and y is greater than 5")
    else:
        print("x is greater than 5")
else:
    print("x is not greater than 5")
# Out:
# x and y is greater than 5

# %%
a = "nnikhilll"
b = list(a)
b.sort()
print(b)
# Out:
# ['h', 'i', 'i', 'k', 'l', 'l', 'l', 'n', 'n']

# %%
d={}
for j in a:
    d[j]=b.count(j)
print(d)
# Out:
# {'n': 2, 'i': 2, 'k': 1, 'h': 1, 'l': 3}
