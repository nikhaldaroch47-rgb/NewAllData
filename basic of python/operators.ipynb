# %%
# arthematic operators..
a = 5
b = 6
a-b
# Out:
# -1

# %%
b = 4*5
print(b)
c= 20/5
print(c)
d = 31%5
print(d)
# Out:
# 20
# 4.0
# 1

# %%
2**10  # two astric value means power
# Out:
# 1024

# %%
a = 4/3
print(a)
b = 4//3 # ->> flour operator in this we get closet interger value..
print(b)
# Out:
# 1.3333333333333333
# 1

# %%
#compariso operator..
3==3
# Out:
# True

# %%
a =3>2
print(a)
b = 4<3
print(b)
c = 4!=3
print(c)
# Out:
# True
# False
# True

# %%
#logical operator..

True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
# not opertor
not True # ->> similar with not false is true..
# Out:
# False

# %%
# assignment operator
a = 6
a = a+10
a
# Out:
# 16

# %%
b = 10 
b+=20 # both b+=20 and b = b+20 is same but the syntax is different 
b
# Out:
# 30

# %%
a = 10 
a+=20
a
# Out:
# 30

# %%
b= 20 
b/=5
b
# Out:
# 4.0

# %%
# membership operator..
r = "nikhil"
print("n" in r)
list =  ["nikhil",2,3,"sukh"]
print("sukh" in list)
# Out:
# True
# True

# %%
# indentity operator.. ->> is used to compare to varriables..
a = 2
b = 3  # both a and b pointing to different memory locations 
print(a is b)
# now
a = 2
b = a  # both a and b pointing to same memory location
print(a is b)
# Out:
# False
# True

# %%
# BIT WISE OERATOR ->> OPERTAORS AT BIT LEVEL 
bin(12)
# Out:
# '0b1100'

# %%
3 | 2
# Out:
# 3

# %%
# xor operator 
5 ^ 3
# Out:
# 6

# %%
print(2 ^ 6)
print(bin(2))
print(bin(6))
print(bin(4))
# Out:
# 4
# 0b10
# 0b110
# 0b100

# %%
# SHIFT OPERATOR ->> LEFT SHIFT AND RIGHT SHIFT..
35 << 3 # left shift is denoted with <<  now 35 is 100011 adding 3 zeros on left side and the binary value represent 280
# Out:
# 280

# %%
bin(280)
# Out:
# '0b100011000'

# %%
print(10 >> 1)
print(bin(5))
print(bin(10))
# Out:
# 5
# 0b101
# 0b1010

# %%
# right shift means to remove the elements from the right side
