# %%
# TYPE CASTING ->>> CHANGING THE DATA TYPE INTO ANOTHER DATA TYPE IS CALLED TYPE CASTING...
a = "2"  # we cannot add string to interger so to add we have to change strint to integer
b = 3
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 a = "2"  # we cannot add string to interger so to add we have to change strint to integer
#       3 b = 3
# ----> 4 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(int(a) + b)

print(type(int(a)))
# Out:
# 5
# <class 'int'>

# %%
f = 3.6
print(int(f))
print(type(int(f)))
# Out:
# 3
# <class 'int'>

# %%
# interger to string
a = 5 
str(a)
# Out:
# '5'

# %%
# implicit typecasting ->> when python automaticaly converts one data type to another. python has tendency to understand data type on its own

#for example
b = 5
type(b)
# Out:
# int

# %%
a = "nikhil"
b = " daroch"
a+b # concatination ->> adding the strings..
# Out:
# 'nikhil daroch'

# %%
# interger to float
a = int(3)
float(a)
# Out:
# 3.0

# %%
# explicit type casting that we can manually convert one data tyep to another using buit in functions..
