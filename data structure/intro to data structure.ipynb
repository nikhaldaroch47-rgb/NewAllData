# %%
l = [1,2,3,4,5,6]
#l[6]  # list index out of range
# list can store any data
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# append is function used to add elements in  a lsit
l = [1,2,3,4,"sukh","nikhil"]
l.append("veer")
l.remove("nikhil") # remove element from list
print(l)
# Out:
# [1, 2, 3, 4, 'sukh', 'veer']

# %%
# tuple ->> is a immutable 
t = (1,2,3,44,5) # tuple can heterogenous data
type(t)
# Out:
# tuple

# %%
a = (1,2,3)
b = (4,5,6)
c = (a,b)
print(c)
for i in c:
    for j in i:
        print(j)
# Out:
# ((1, 2, 3), (4, 5, 6))
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# sets ->> unordered collection of unique elements..
a = {1,1,2,2,3,3}
a.add("nikhil") # no concept of indexing in sets... in sets we can add the element and also we can remove the elements
print(a)
# Out:
# {1, 2, 3, 'nikhil'}

# %%
# dictnaroies 
d = {"course" : "data sturcture" , "duration" : 200}
d
# Out:
# {'course': 'data sturcture', 'duration': 200}

# %%
phone_book = {"saloni" : 9501022100 , "simran" : 9501586046}

phone_book["simran"]
# Out:
# 9501586046

# %%
phone_book.keys()
phone_book.values()
# Out:
# dict_values([9501022100, 9501586046])

# %%
# array is same like list but will only store homogenous data
