# %%
# LISTS ->> can store any data type.. and list are mutalble means can interchange any value

# %%
list = [1,"nikhil",True,3.4,3+5j]
type(list)
print(list[0:]) # slicing is possible
# Out:
# [1, 'nikhil', True, 3.4, (3+5j)]

# %%
a =[1,2,3,4,5,"nikhil"]
a.append("meetu")
a[0] = "love"
a
# Out:
# ['love', 2, 3, 4, 5, 'nikhil', 'meetu']

# %%
subjects = ["science","hindi","punjabi","english","sst"]
subjects.insert(1,"maths") # -->> insert element before index
subjects
# Out:
# ['science', 'maths', 'hindi', 'punjabi', 'english', 'sst']

# %%
# extend - append elemnts from another list
a = [1,2,3]
b = [4,5,6]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"*" * 12
# Out:
# '************'

# %%
[1,2,3] * 5
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# sorting
list = [2,3,7,8,4,6,1,1,1]
sorted(list)
list.index(1)  #->> print the element at that index
list.count(1)  #->> count the no of individual elements
list.remove(1) #->> remove the elemnt from the list
#list.clear()   # ->> del all the elements from the list
list.pop(1)  # remove out the elemnet 
list
# Out:
# [2, 7, 8, 4, 6, 1, 1]

# %%
# LIST COMPREHENSION
price = [10,20,30,40,50]
double =  [i * 2 for i in price]
double
# Out:
# [20, 40, 60, 80, 100]

# %%
for price in range(0,60,10):
    print(price*2)
# Out:
# 0
# 20
# 40
# 60
# 80
# 100

# %%
numbers = [1,2,3,4,5]
[i if i%2==0 else i**2 for i in numbers]
# Out:
# [1, 2, 9, 4, 25]

# %%
n=int(input('enter your no.'))
temp=n
rev=0
while n>0:
    rem=n%10
    rev=rev*10+rem
    n=n//10
if rev==temp:
    print('palindrom')
else:
    print('not palindrom ')

# %%
n=int(input('enter your no.'))
temp=n
rev=0
while temp>0:
    rem=temp%10
    rev=rev*10+rem
    temp=temp//10
if rev==n:
    print('palindrom')
else:
    print('not palindrom ')
