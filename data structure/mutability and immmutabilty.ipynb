# %%
a = "nikhil"
print(a[0]) #we acces the each index by indexing.
# Out:
# n

# %%
list_cont = [1,2,3,5+6j,True,5.3]  #list can store any type of data.
print(list_cont)
print(list_cont[3:6])
type(list_cont)
# Out:
# [1, 2, 3, (5+6j), True, 5.3]
# [(5+6j), True, 5.3]
# list

# %%
# mutability = when we can assing or replace items with another
list =[1,2,3,"sukh"]
list[3]= "rahul"
list[3]
# Out:
# 'rahul'

# %%
# immutability = do not support item assignment
a= "gurnoor"
a[0]="n"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # immutability
#       2 a= "gurnoor"
# ----> 3 a[0]="n"
#
# TypeError: 'str' object does not support item assignment
