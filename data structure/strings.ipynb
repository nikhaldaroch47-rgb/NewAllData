# %%
# ACII REPRESENTATION
char = "A"
ord(char) # ord ->> is a ordinal used to represent a numerical value of character..
# Out:
# 65

# %%
chr(97) # chr ->> is used to represent a character from numerical value..
# Out:
# 'a'

# %%
# UNICODE REPRESENTATION  - >> unicode are used to represent special characters 
# represent omega
"\u03A9"
# Out:
# 'Ω'

# %%
"\u0937"  # hindi words are also represented through unicode
# Out:
# 'ष'

# %%
"\u03A0"
# Out:
# 'Π'

# %%
# strings...
''' i am a student 
 i study in collge 
 and i am a data scientist''' # this backward slash n represent a new line
# Out:
# ' i am a student \n i study in collge \n and i am a data scientist'

# %%
# concatination 
a = "nikhil"
b = " daroch"
a+b
# Out:
# 'nikhil daroch'

# %%
"string" + " ->>" + " concatination" + " ->>" + " adding to strings"
# Out:
# 'string ->> concatination ->> adding to strings'

# %%
# slicing 
s = "nikhil"
print(s[0:])
b = "i am a good student"
print(b[:-1]) # [:-1] - >> means remove only last element  # [included:excluded]    [::-2]  it means no starting no ending and one one elements from string
print(s[4])
# Out:
# nikhil
# i am a good studen
# i

# %%
A = "nikhil daroch"
A[::2]  # this means skip one one elemnt ,,, [::-1 iterate from last]
# Out:
# 'nki aoh'

# %%
# we can also repkace the elemnets in strings
c = "Nikhil Love Meetu"
print(c.replace("love", "very love").replace("nikhil","sukh").replace("meetu","veet"))
print(c.swapcase())  # swapcase will convert the upper case into lower case and lower case into upper case
# Out:
# Nikhil Love Meetu
# nIKHIL lOVE mEETU

# %%
a = "my name is nikhil"
if ("nikhil" in a):
    print("present in a")
else:
    print("not present")
# Out:
# present in a

# %%
product_code = "p123"
scanned_code = "p1234"
if product_code == scanned_code:
    print("price is 100")
else:
    print("not matched")
# Out:
# not matched

# %%
# string ordering
name = ["nikhil","aman","rahul","sukh","pratham"]
sorted(name)
# Out:
# ['aman', 'nikhil', 'pratham', 'rahul', 'sukh']

# %%
# string splitting
A = "nikhil, data science, student"
A.split(",")
# Out:
# ['nikhil', ' data science', ' student']

# %%
# escape characters = special combination of characters..
addres = """arman nagar,
dakoha jalandhar cantt."""
print(addres) # \n ->> to insert a new line
# Out:
# arman nagar,
# dakoha jalandhar cantt.

# %%
# \t character
table = "name\tage\tgrade\nnikhil\t21\tA\nsukha\t20\tB"
print(table)
# Out:
# name	age	grade
# nikhil	21	A
# sukha	20	B

# %%
# carrige return 
a = "hello i am nikhil \ri live in punjab ,dist jalandhar"
print(a)
# Out:
# i live in punjab ,dist jalandhar

# %%
# string formatting ->> creating placeholders
name = "nikhil"
greetings = f"hello {name} how are u?"
print(greetings)
# Out:
# hello nikhil how are u?

# %%
collge_name = "daviet"
cource_duration = 4 
f"my college name is {collge_name} and my course duration is {cource_duration} years"
# Out:
# 'my college name is daviet and my course duration is 4 years'

# %%
email_id = "nikhil@gmail.com"
phone_model = "realme c3"
f"hi, my email id is {email_id} and my phone name is {phone_model}"
# Out:
# 'hi, my email id is nikhil@gmail.com and my phone name is realme c3'

# %%
a = "abc123"
a.isalnum()
# Out:
# True

# %%
b = "123"
b.isalnum()
# Out:
# True
