# %%
open("nikhil.txt",'r')   # it will throw an error because no sunch file nikhil.txt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 open("nikhil.txt",'r')
#
# File c:\Users\Nikhal\anaconda31\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nikhil.txt'

# %%
nikhil = open("nikhil.txt","w") # w means if file is not it will create it first 
nikhil.write("nikhil from this side welcome to the world of god") # number below is number of bytes
# Out:
# 49

# %%
nikhil.close() # this is to open the file and read it
nikhil.closed
# Out:
# True

# %%
nikhil = open("nikhil.txt","r")
nikhil.closed
nikhil.name
nikhil.mode
# Out:
# 'r'

# %%
nikhil.write("helo this is muskan")  # file is closed we cannot write any thing
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 nikhil.write("helo this is muskan")
#
# UnsupportedOperation: not writable

# %%
nikhil = open("nikhil.txt","w")  # previous content willl be delated
nikhil.write("this my second line\n")
nikhil.write("this is my third line\n")
nikhil.close()

# %%
nikhil = open("nikhil.txt","a") # a ->> append not del previous content
nikhil.write("this is fourth line\n")
nikhil.close()

# %%
nikhil = open("nikhil.txt","r")

# %%
for i in nikhil:
    print(i)
# Out:
# this my second line
#
# this is my third line
#
# this is fourth line

# %%
print(nikhil.read())  # here the pointer is at last position

# %%
nikhil.tell() # tell the current position of cursor
# Out:
# 65

# %%
nikhil.seek(0)
# Out:
# 0

# %%
f = open("nikhil.txt","r")
f.seek(0)  # it will point the cursor at first line 
print(f.read()) # it will read the whole lines
# Out:
# this my second line
# this is my third line
# this is fourth line

# %%
f = open("nikhil.txt","r")
print(f.readline()) # it will read the first line
f.close()
# Out:
# this my second line

# %%
# presemt working directory
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Nikhal\\OneDrive\\Documents\\pdf files'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 860B-D5C8
#
#  Directory of c:\Users\Nikhal\OneDrive\Documents\pdf files
#
# 21-12-2025  20:14    <DIR>          .
# 15-11-2025  22:13    <DIR>          ..
# 21-12-2025  19:41    <DIR>          basic of python
# 20-10-2025  14:59    <DIR>          chapter 1
# 07-11-2025  12:35    <DIR>          data structure
# 21-12-2025  20:11             5,369 file handling.ipynb
# 07-11-2025  12:37    <DIR>          functions
# 11-09-2025  12:33             3,120 mutability and immmutabilty.ipynb
# 21-12-2025  20:23                65 nikhil.txt
# 09-11-2025  22:46    <DIR>          oops
# 16-12-2025  22:23               597 oops 2.py
# 16-12-2025  21:38    <DIR>          questions
# 02-12-2025  13:39             6,355 questions = 2.ipynb
# 07-11-2025  12:59            10,697 strings.ipynb
# 22-09-2025  22:52             4,292 type casting.ipynb
#                7 File(s)         30,495 bytes
# ...

# %%
os.path.getsize("nikhil.txt")
# Out:
# 65

# %%
muskan = open("muskan.txt",'w')
muskan.write("i am from canada and working as teacher \n")
muskan.close()

# %%
muskan = open("muskan.txt","a")
muskan.write("and i am nikhil sister")
muskan.close()
