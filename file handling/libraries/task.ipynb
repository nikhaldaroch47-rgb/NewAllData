# %%
import pandas as pd

# %%
data = pd.Series([100, 200, 300, 400], index=['x', 'y', 'z', 'w']) 
data.loc["y"]
# Out:
# np.int64(200)

# %%
data.iloc[2]
# Out:
# np.int64(300)

# %%
data.loc["x":"w"]
# Out:
# x    100
# y    200
# z    300
# w    400
# dtype: int64

# %%
data.iloc[3]
# Out:
# np.int64(400)

# %%
data.loc["y":"z"]
# Out:
# y    200
# z    300
# dtype: int64

# %%
# in interger based inddex

# loc[2]  --> means we get the element present at 2nd index loc is location for labels and using indexes
# iloc[2] --> we get the element present at 2nd index in this we get elements using indxes

# %%
data.x
# Out:
# np.int64(100)
