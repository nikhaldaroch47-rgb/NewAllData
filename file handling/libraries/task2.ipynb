# %%
import pandas as pd

data = {
'Name' : ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 
'Age' : [25, 30, 35, 40, 45], 
'Department' :  ['HR', 'IT', 'Finance', 'Marketing', 'Operations']
}

# %%
dataframe = pd.DataFrame(data)
dataframe
# Out:
#       Name  Age  Department
# 0    Alice   25          HR
# 1      Bob   30          IT
# 2  Charlie   35     Finance
# 3    David   40   Marketing
# 4      Eve   45  Operations

# %%
dataframe[dataframe.loc[:,'Age']>30]
# Out:
#       Name  Age  Department
# 2  Charlie   35     Finance
# 3    David   40   Marketing
# 4      Eve   45  Operations

# %%
dataframe.iloc[3,:]
# Out:
# Name              David
# Age                  40
# Department    Marketing
# Name: 3, dtype: object

# %%
dataframe.iloc[:,:2]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4      Eve   45

# %%
dataframe.iloc[:3,:2]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
dataframe.loc[3,"Age"]=42
dataframe
# Out:
#       Name  Age  Department
# 0    Alice   25          HR
# 1      Bob   30          IT
# 2  Charlie   35     Finance
# 3    David   42   Marketing
# 4      Eve   45  Operations

# %%
dataframe
# Out:
#       Name  Age  Department
# 0    Alice   25          HR
# 1      Bob   30          IT
# 2  Charlie   35     Finance
# 3    David   40   Marketing
# 4      Eve   45  Operations

# %%
it_index=dataframe[dataframe.loc[:,'Department']=='IT'].index

# %%
it_index
# Out:
# Index([1], dtype='int64')

# %%
dataframe.loc[it_index,'Department']='Tech Support'

# %%
dataframe
# Out:
#       Name  Age    Department
# 0    Alice   25            HR
# 1      Bob   30  Tech Support
# 2  Charlie   35       Finance
# 3    David   40     Marketing
# 4      Eve   45    Operations

# %%
dataframe
# Out:
#       Name  Age    Department
# 0    Alice   25            HR
# 1      Bob   30  Tech Support
# 2  Charlie   35       Finance
# 3    David   40     Marketing
# 4      Eve   45    Operations

# %%
dataframe.iloc[2,1]=32
dataframe
# Out:
#       Name  Age    Department
# 0    Alice   25            HR
# 1      Bob   30  Tech Support
# 2  Charlie   32       Finance
# 3    David   40     Marketing
# 4      Eve   45    Operations
