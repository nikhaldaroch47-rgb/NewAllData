# %%
# by arthur samuel -- subfield of computer science that gives computer a 
# abilityy to learn without explicitly programmed 
# (ability to learn pateerns in data)
# machine learn pattern from data and replicate in future

# %%
# why ml famous these days 
# advanced processors

# %%
# AI , ML , DL , DS

# ARTIFICIAL INTELLINGE -->> SMART MACHINE CAN PERFORM TASK WITHOUT HUMAN INTERFERENCE

# %%
# MACHINE LEARNING -->> THAT FOCUS ON CREATING ALGORITHMS AND STATTICAL MODELS TO LET COMPUTER LEARN AND MAKE PERDICATION WITHOUT ANY PROGRAM

# LEARN PATTERS FROM --> THROUGHT ALGORITHMS
# EX - PRICE OF HOUSE , DIABITIC AND NON DIABETIC

# %%
# DEEP LEARNING -->> THESE ARE SPECIALISED ML AGLO THAT MIMICS HUMAN BRAIN

# %%
# DATA SCIENCE --> WHEMN WE HAVE TO PERFORM SOME TASK ON DATA WITH THE HELP OF STATS ,ML ETC TO GET THE NECESSARY INSIGHTS FROM DATA

# %%
# TYPES OF MACHINE LEARNING 
# SUPERVISED LEARNING  
# UNSUPERVISED LEARNING
# SEMI SUPERVISED 
# REENFORCEMENT

# %%
''' SUPERVISED LEARNING -->>      AREA OF HOUSE    |   NO OF ROOMS  | PRICE OF HOUSE (Y)
                                     THESE ARE INDEPENDENT       |    DEPENDENT VARIABLE / TARGET VARIABLE 
Y = F(X)  FOR EX F(1100,3)= 3.2CR 


SUPERVISED LEARNING OF TWOO TYPES -> REGERSION , AND CLASIFICATION

REGRESION ->>  Y IS CONTINOUS,, EX PRICE OF HOUSE 


CLASIFICATION -->> Y IS DISCRETE ,, EX PASS OR FAIL

IN CLASIFICATION IF Y IS TAKING ONLY TWO VALUES THEN IT IS BINARY CLASIFICATION AND IF IT TAKE 
MULTIPLE THAN IT IS MULTICLASS CLASIFICATION '''
# Out:
# ' SUPERVISED LEARNING -->>      AREA OF HOUSE    |   NO OF ROOMS  | PRICE OF HOUSE (Y)\n                                     THESE ARE INDEPENDENT       |    DEPENDENT VARIABLE / TARGET VARIABLE \nY = F(X)  FOR EX F(1100,3)= 3.2CR \n\n\nSUPERVISED LEARNING OF TWOO TYPES -> REGERSION , AND CLASIFICATION\n\nREGRESION ->>  Y IS CONTINOUS,, EX PRICE OF HOUSE \n\n\nCLASIFICATION -->> Y IS DISCRETE ,, EX PASS OR FAIL\n\nIN CLASIFICATION IF Y IS TAKING ONLY TWO VALUES THEN IT IS BINARY CLASIFICATION AND IF IT TAKE \nMULTIPLE THAN IT IS MULTICLASS CLASIFICATION '

# %%
''' UNSUPERVISED LEARNING MEANS (NO SUPERVISION )  ,, NO Y AND NO HISTORICAL DATA '''
# Out:
# ' UNSUPERVISED LEARNING MEANS (NO SUPERVISION )  ,, NO Y AND NO HISTORICAL DATA '

# %%
''' SEMI SUPERVISED DATA  -->> COMBINATION OF BOTH SUPERVISED AND UNSUPERVISED LEARNING'''

# %%
''' REINFORCEMENT LEARNING  --> CONCERNED WITH HOW INTELLEGENT AGENT TAKE ACTIONS IN AN 
ENVIROMENT TO MAXIMIZE THE AWARD
