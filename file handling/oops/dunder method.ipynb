# %%
# dunder method/magic method

# %%
print("hello world") # print is a keyword in built function

# %%
# dunder method are the methods defined by built in classes in python 
# classes define these type of method for creating (custom objects)-->> for init it means data for every object
#

# %%
# d + under -->> double underscore in very object double underscore before and after is dunder method

# %%
a = "nikhil"
b = " meetu"
a+b
# Out:
# 'nikhil meetu'
