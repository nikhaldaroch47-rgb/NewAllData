# %%
import pandas as pd

# %%
df = pd.read_csv("services.csv")
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.describe() # stastical infomation about numerical columns
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
df[["location_id","program_id","accepted_payments"]]
# Out:
#     location_id  program_id         accepted_payments
# 0             1         NaN                       NaN
# 1             2         NaN                       NaN
# 2             3         NaN                       NaN
# 3             4         NaN                       NaN
# 4             5         NaN                       NaN
# 5             6         NaN                       NaN
# 6             7         NaN                       NaN
# 7             8         NaN                       NaN
# 8             9         NaN                       NaN
# 9            10         NaN                       NaN
# 10           11         NaN                       NaN
# 11           12         NaN                       NaN
# 12           13         NaN                       NaN
# 13           14         NaN                       NaN
# 14           15         NaN                       NaN
# 15           16         NaN                       NaN
# ...

# %%
df[df.dtypes[df.dtypes != "object"].index].describe()  # object is a string
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
df.describe(include="object")   # if we include all means all the info merged together   # instead of numerical columns is included / categorical information
# Out:
#                accepted_payments         alternate_name application_process  \
# count                          1                      1                  23
# unique                         1                      1                  20
# top     Cash, Check, Credit Card  Fotos para pasaportes     Apply by phone.
# freq                           1                      1                   2
#
#                                                  audience  \
# count                                                  14
# unique                                                 14
# top     Older adults age 55 or over, ethnic minorities...
# freq                                                    1
#
#                                               description  \
# count                                                  23
# unique                                                 23
# top     A walk-in center for older adults that provide...
# ...

# %%
df.astype("object").describe()  # treat all the columns as categorical data
# Out:
#         id  location_id program_id         accepted_payments  \
# count   23           23          0                         1
# unique  23           22          0                         1
# top      1           22        NaN  Cash, Check, Credit Card
# freq     1            2        NaN                         1
#
#                alternate_name application_process  \
# count                       1                  23
# unique                      1                  20
# top     Fotos para pasaportes     Apply by phone.
# freq                        1                   2
#
#                                                  audience  \
# count                                                  14
# unique                                                 14
# top     Older adults age 55 or over, ethnic minorities...
# freq                                                    1
#
#                                               description  \
# ...

# %%
df.shape
# Out:
# (23, 22)

# %%
df[0:20:5]
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 0    1            1         NaN               NaN            NaN
# 5    6            6         NaN               NaN            NaN
# 10  11           11         NaN               NaN            NaN
# 15  16           16         NaN               NaN            NaN
#
#                                   application_process  \
# 0                          Walk in or apply by phone.
# 5   Walk in or apply by phone for membership appli...
# 10  Walk in. Proof of California residency require...
# 15  Walk in. Written application, identification r...
#
#                                              audience  \
# 0   Older adults age 55 or over, ethnic minorities...
# 5                                             Any age
# 10                                                NaN
# 15                                                NaN
#
#                                           description  \
# ...

# %%
df["new_column"] = "nikhil"
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# sum of location_id and program_id
df["addition"] = df["location_id"] + df["program_id"]
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# df.isnull()
df.isnull().any()
# Out:
# id                         False
# location_id                False
# program_id                  True
# accepted_payments           True
# alternate_name              True
# application_process        False
# audience                    True
# description                False
# eligibility                 True
# email                       True
# fees                        True
# funding_sources             True
# interpretation_services     True
# keywords                    True
# languages                   True
# name                       False
# required_documents          True
# service_areas               True
# status                     False
# wait_time                   True
# website                     True
# taxonomy_ids                True
# dtype: bool

# %%
# fill or del 
df.drop("program_id",axis=1,inplace=True)   # will del all rows becoz have all hve none values

# %%
df
# Out:
# Empty DataFrame
# Columns: [id, location_id, accepted_payments, alternate_name, application_process, audience, description, eligibility, email, fees, funding_sources, interpretation_services, keywords, languages, name, required_documents, service_areas, status, wait_time, website, taxonomy_ids, addition]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.isna().sum()   # sum of all null values present in each column
# Out:
# id                          0
# location_id                 0
# program_id                 23
# accepted_payments          22
# alternate_name             22
# application_process         0
# audience                    9
# description                 0
# eligibility                 6
# email                      22
# fees                        2
# funding_sources             2
# interpretation_services    22
# keywords                    2
# languages                  22
# name                        0
# required_documents         22
# service_areas               2
# status                      0
# wait_time                   4
# website                    21
# taxonomy_ids               22
# dtype: int64

# %%
df["accepted_payments"].unique()
# df["application_process"].nunique()
# Out:
# array([nan, 'Cash, Check, Credit Card'], dtype=object)

# %%
len(df["location_id"].value_counts())
# Out:
# 22

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...
