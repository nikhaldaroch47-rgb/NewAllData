# %%
import pandas as pd

# %%
data = pd.read_csv("taxonomy.csv")
data
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data.tail()
# Out:
#              0                             1       2                     3
# 286  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 287     111-02                     Mediation     111                 Legal
# 288     111-03                        Notary     111                 Legal
# 289     111-04                Representation     111                 Legal
# 290     111-05  Translation & Interpretation     111                 Legal

# %%
data.head()
# Out:
#              0                  1          2               3
# 0  taxonomy_id               name  parent_id     parent_name
# 1          101          Emergency        NaN             NaN
# 2       101-01  Disaster Response        101       Emergency
# 3       101-02     Emergency Cash        101       Emergency
# 4    101-02-01  Help Pay for Food     101-02  Emergency Cash

# %%
data.shape
# Out:
# (291, 4)

# %%
data.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# ...

# %%
data[0:20:2]
# Out:
#               0                               1          2                 3
# 0   taxonomy_id                            name  parent_id       parent_name
# 2        101-01               Disaster Response        101         Emergency
# 4     101-02-01               Help Pay for Food     101-02    Emergency Cash
# 6     101-02-03            Help Pay for Housing     101-02    Emergency Cash
# 8     101-02-05             Help Pay for School     101-02    Emergency Cash
# 10       101-03                  Emergency Food        101         Emergency
# 12       101-05       Help Find Missing Persons        101         Emergency
# 14    101-06-01            Help Escape Violence     101-06  Immediate Safety
# 16       101-07  Psychiatric Emergency Services        101         Emergency
# 18       102-01               Community Gardens        102              Food

# %%
# revise accesing the data in dataframes

# %%
# implicit indexing

# %%
# data.iloc[0:3]  # iloc always require internal indexes
# Out:
#              0                  1          2            3
# 0  taxonomy_id               name  parent_id  parent_name
# 1          101          Emergency        NaN          NaN
# 2       101-01  Disaster Response        101    Emergency

# %%
# explicit or named indexing

data.loc[0:3]
# Out:
#              0                  1          2            3
# 0  taxonomy_id               name  parent_id  parent_name
# 1          101          Emergency        NaN          NaN
# 2       101-01  Disaster Response        101    Emergency
# 3       101-02     Emergency Cash        101    Emergency

# %%
data.loc[0:5,["taxonomy_id","name"]]
# Out:
#   taxonomy_id                     name
# 0         101                Emergency
# 1      101-01        Disaster Response
# 2      101-02           Emergency Cash
# 3   101-02-01        Help Pay for Food
# 4   101-02-02  Help Pay for Healthcare
# 5   101-02-03     Help Pay for Housing

# %%
data["taxonomy_id"][2:5]
# Out:
# 2       101-02
# 3    101-02-01
# 4    101-02-02
# Name: taxonomy_id, dtype: object

# %%
s = pd.Series(list(data["taxonomy_id"][2:5]))
s
# Out:
# 0       101-02
# 1    101-02-01
# 2    101-02-02
# dtype: object

# %%
data.drop("taxonomy_id",axis=True) #inplace means to change in original
# Out:
#                              name parent_id           parent_name
# 0                       Emergency       NaN                   NaN
# 1               Disaster Response       101             Emergency
# 2                  Emergency Cash       101             Emergency
# 3               Help Pay for Food    101-02        Emergency Cash
# 4         Help Pay for Healthcare    101-02        Emergency Cash
# ..                            ...       ...                   ...
# 285              Workplace Rights    111-01  Advocacy & Legal Aid
# 286                     Mediation       111                 Legal
# 287                        Notary       111                 Legal
# 288                Representation       111                 Legal
# 289  Translation & Interpretation       111                 Legal
#
# [290 rows x 3 columns]

# %%
data.astype("object").describe()  # treat all as categorial data  ,, describe -->> statistical info of num columns
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top         111-05  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
data.reset_index(drop=True)
data
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data.set_index("name",inplace=True)

# %%
data
# Out:
#                              taxonomy_id parent_id           parent_name
# name
# Emergency                            101       NaN                   NaN
# Disaster Response                 101-01       101             Emergency
# Emergency Cash                    101-02       101             Emergency
# Help Pay for Food              101-02-01    101-02        Emergency Cash
# Help Pay for Healthcare        101-02-02    101-02        Emergency Cash
# ...                                  ...       ...                   ...
# Workplace Rights               111-01-07    111-01  Advocacy & Legal Aid
# Mediation                         111-02       111                 Legal
# Notary                            111-03       111                 Legal
# Representation                    111-04       111                 Legal
# Translation & Interpretation      111-05       111                 Legal
#
# [290 rows x 3 columns]

# %%
data.loc["Emergency"]
# Out:
# taxonomy_id    101
# parent_id      NaN
# parent_name    NaN
# Name: Emergency, dtype: object

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.isnull().sum()
# Out:
# taxonomy_id     0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
data.dropna()  # will drop all null values from rows
# Out:
#     taxonomy_id parent_id           parent_name
# 1        101-01       101             Emergency
# 2        101-02       101             Emergency
# 3     101-02-01    101-02        Emergency Cash
# 4     101-02-02    101-02        Emergency Cash
# 5     101-02-03    101-02        Emergency Cash
# ..          ...       ...                   ...
# 285   111-01-07    111-01  Advocacy & Legal Aid
# 286      111-02       111                 Legal
# 287      111-03       111                 Legal
# 288      111-04       111                 Legal
# 289      111-05       111                 Legal
#
# [279 rows x 3 columns]

# %%
# inputation --> means replacing missing values with some other values 
# numerical value will be replaced with mean and median and outlayers will be replaced with meadian
# categorial data --> will be replaced with mode

# %%
data.fillna(0)  # this will used to fill null values
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
d = {"A" : [1,2,None,3,4,5,None],
      "B" : [6,None,7,8,None,None,9]
}

# %%
df = pd.DataFrame(d)
df
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  NaN
# 2  NaN  7.0
# 3  3.0  8.0
# 4  4.0  NaN
# 5  5.0  NaN
# 6  NaN  9.0

# %%
df["A"].mean()
# Out:
# np.float64(3.0)

# %%
df["A"].fillna(df["A"].mean())  # will fill all the nan values with mean of A
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    4.0
# 5    5.0
# 6    3.0
# Name: A, dtype: float64

# %%
df.duplicated().sum()  # want to see duplicate rows
# Out:
# np.int64(0)

# %%
data["name"]
# Out:
# 0                         Emergency
# 1                 Disaster Response
# 2                    Emergency Cash
# 3                 Help Pay for Food
# 4           Help Pay for Healthcare
#                    ...
# 285                Workplace Rights
# 286                       Mediation
# 287                          Notary
# 288                  Representation
# 289    Translation & Interpretation
# Name: name, Length: 290, dtype: object
