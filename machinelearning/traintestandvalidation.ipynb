# %%
# in school 
# teatcher   -----      pre board     ------      board 
# (trained here )     (validation)           (tested externaly)

# %%
# machine learning -- > means learning patterns from data  
# notes in copy
